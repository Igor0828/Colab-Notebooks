# %% [markdown]
# ***
# # <font color=green size=10>CURSO DE ESTATÍSTICA - PARTE 2</font>
# ***
#
# ## Trabalho sobre Probabilidades, Amostragem e Estimações
#
# Utilizando os conhecimentos adquiridos em nosso treinamento execute as tarefas abaixo. Siga o roteiro proposto e vá completando as células vazias.

# %% [markdown]
# # <font color=green>DATASET DO PROJETO</font>
# ***

# %% [markdown]
# ### Pesquisa Nacional por Amostra de Domicílios - 2015
#
# A <b>Pesquisa Nacional por Amostra de Domicílios - PNAD</b> investiga anualmente, de forma permanente, características gerais da população, de educação, trabalho, rendimento e habitação e outras, com periodicidade variável, de acordo com as necessidades de informação para o país, como as características sobre migração, fecundidade, nupcialidade, saúde, segurança alimentar, entre outros temas. O levantamento dessas estatísticas constitui, ao longo dos 49 anos de realização da pesquisa, um importante instrumento para formulação, validação e avaliação de políticas orientadas para o desenvolvimento socioeconômico e a melhoria das condições de vida no Brasil.

# %% [markdown]
# ### Fonte dos Dados
#
# https://ww2.ibge.gov.br/home/estatistica/populacao/trabalhoerendimento/pnad2015/microdados.shtm

# %% [markdown]
# ### Variáveis utilizadas
#
# > ### Renda
# > ***
#
# Rendimento mensal do trabalho principal para pessoas de 10 anos ou mais de idade.
#
# > ### Idade
# > ***
#
# Idade do morador na data de referência em anos.
#
# > ### Altura (elaboração própria)
# > ***
#
# Altura do morador em metros.
#
# > ### UF
# > ***
#
# |Código|Descrição|
# |---|---|
# |11|Rondônia|
# |12|Acre|
# |13|Amazonas|
# |14|Roraima|
# |15|Pará|
# |16|Amapá|
# |17|Tocantins|
# |21|Maranhão|
# |22|Piauí|
# |23|Ceará|
# |24|Rio Grande do Norte|
# |25|Paraíba|
# |26|Pernambuco|
# |27|Alagoas|
# |28|Sergipe|
# |29|Bahia|
# |31|Minas Gerais|
# |32|Espírito Santo|
# |33|Rio de Janeiro|
# |35|São Paulo|
# |41|Paraná|
# |42|Santa Catarina|
# |43|Rio Grande do Sul|
# |50|Mato Grosso do Sul|
# |51|Mato Grosso|
# |52|Goiás|
# |53|Distrito Federal|
#
# > ### Sexo
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Masculino|
# |1|Feminino|
#
# > ### Anos de Estudo
# > ***
#
# |Código|Descrição|
# |---|---|
# |1|Sem instrução e menos de 1 ano|
# |2|1 ano|
# |3|2 anos|
# |4|3 anos|
# |5|4 anos|
# |6|5 anos|
# |7|6 anos|
# |8|7 anos|
# |9|8 anos|
# |10|9 anos|
# |11|10 anos|
# |12|11 anos|
# |13|12 anos|
# |14|13 anos|
# |15|14 anos|
# |16|15 anos ou mais|
# |17|Não determinados|
# ||Não aplicável|
#
# > ### Cor
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Indígena|
# |2|Branca|
# |4|Preta|
# |6|Amarela|
# |8|Parda|
# |9|Sem declaração|

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > Os seguintes tratamentos foram realizados nos dados originais:
# > 1. Foram eliminados os registros onde a <b>Renda</b> era inválida (999 999 999 999);
# > 2. Foram eliminados os registros onde a <b>Renda</b> era missing;
# > 3. Foram considerados somente os registros das <b>Pessoas de Referência</b> de cada domicílio (responsável pelo domicílio).

# %% [markdown]
# ***
# ***

# %% [markdown]
# ### Utilize a célula abaixo para importar as bibliotecas que precisar para executar as tarefas
# #### <font color='red'>Sugestões: pandas, numpy, scipy etc.</font>

# %%
import pandas as pd
import numpy as np
from scipy.stats import binom
from scipy.stats import norm

# %% [markdown]
# ### Importe o dataset e armazene o conteúdo em uma DataFrame

# %%
dados = pd.read_csv('dados.csv')

# %% [markdown]
# ### Visualize o conteúdo do DataFrame

# %%
dados.head(5)
# Out:
#    UF  Sexo  Idade  Cor  Anos de Estudo  Renda    Altura
# 0  11     0     23    8              12    800  1.603808
# 1  11     1     23    2              12   1150  1.739790
# 2  11     1     35    8              15    880  1.760444
# 3  11     0     46    2               6   3500  1.783158
# 4  11     1     47    8               9    150  1.690631

# %% [markdown]
# # <font color='green'>Problema A</font>

# %% [markdown]
# Avaliando nosso dataset é possível verificar que a **proporção de homens** como chefes de domicílios é de quase **70%**. Precisamos **selecionar aleatoriamente grupos de 10 indivíduos** para verificar as diferenças entre os rendimentos em cada grupo. Qual a **probabilidade de selecionamos um grupo que apresente a mesma proporção da população**, ou seja, selecionarmos um grupo que seja **composto por 7 homens e 3 mulheres**?
#
# #### <font color='blue'>Como tarefa extra, verifique a real proporção de homens e mulheres em nosso dataset (vimos como fazer isso em nosso primeiro curso de estatística).</font>
#
# #### <font color='red'>Verifique que tipo de distribuição de probabilidade se encaixa neste experimento.</font>

# %% [markdown]
# ### Solução

# %%
k = 7

n = 10

p = 0.70

probabilidade = binom.pmf(k, n, p)
print('%0.8f' % (probabilidade))
# Out:
# 0.26682793

# %% [markdown]
# # <font color='green'>Problema B</font>

# %% [markdown]
# Ainda sobre a questão anterior, **quantos grupos de 10 indivíduos** nós precisaríamos selecionar, de forma aleatória, para conseguir **100 grupos compostos por 7 homens e 3 mulheres**?
#
# #### <font color='red'>Lembre-se da forma de cálculo da média de uma distribuição binomial</font>

# %% [markdown]
# ### Solução

# %%
media = n * p
n = media / p

n = 100 / probabilidade
n = int(n.round())
n
# Out:
# 375

# %% [markdown]
# # <font color='green'>Problema C</font>

# %% [markdown]
# Um cliente nos encomendou um estudo para avaliar o **rendimento dos chefes de domicílio no Brasil**. Para isso precisamos realizar uma nova coleta de dados, isto é, uma nova pesquisa de campo. Após reunião com o cliente foi possível elencar o seguinte conjunto de informações:
#
# > A. O resultado da pesquisa precisa estar pronto em **2 meses**;
#
# > B. Teremos somente **R$\$$ 150.000,00** de recursos para realização da pesquisa de campo; e
#
# > C. Seria interessante uma **margem de erro não superior a 10% em relação a média estimada**.
#
# Em nossa experiência com estudos deste tipo, sabemos que o **custo médio por indivíduo entrevistado fica em torno de R$\$$ 100,00**. Com este conjunto de fatos avalie e obtenha o seguinte conjunto de informações para passar ao cliente:
#
#
# > 1. Para obter uma estimativa para os parâmetros da população (renda dos chefes de domicílio no Brasil), realize uma amostragem aleatória simples em nosso conjunto de dados. Essa amostra deve conter 200 elementos (utilize random_state = 101 para garantir que o mesmo experimento posso ser realizado novamente). Obtenha a média e o desvio-padrão dessa amostra.
#
# > 2. Para a **margem de erro** especificada pelo cliente obtenha os **tamanhos de amostra** necessários para garantir os **níveis de confiança de 90%, 95% e 99%**.
#
# > 3. Obtenha o **custo da pesquisa** para os três níveis de confiança.
#
# > 4. Para o maior nível de confiança viável (dentro do orçamento disponível), obtenha um **intervalo de confiança para a média da população**.
#
# > 5. Assumindo o **nível de confiança escolhido no item anterior**, qual **margem de erro** pode ser considerada utilizando todo o recurso disponibilizado pelo cliente?
#
# > 6. Assumindo um **nível de confiança de 95%**, **quanto a pesquisa custaria ao cliente** caso fosse considerada uma **margem de erro de apenas 5%** em relação a média estimada?

# %% [markdown]
# # <font color='blue'>Solução do item 1</font>

# %% [markdown]
# ### Seleção de uma amostra aleatório simples
#
# #### <font color='red'>Lembre-se de utilizar *random_state = 101*</font>

# %%
# Vamos supor que você tenha um DataFrame chamado 'dados' com a informação de renda dos chefes de domicílio.
# Certifique-se de ajustar o nome do DataFrame conforme necessário.

# Define o random_state para garantir reprodutibilidade
np.random.seed(101)

# Realiza a amostragem aleatória simples de 200 elementos
amostra = dados.sample(n=200)

# Obtém a média e o desvio-padrão da amostra
media_amostra = amostra['Renda'].mean()
desvio_padrao_amostra = amostra['Renda'].std()

# Exibe as informações para o cliente
print(f"Média da amostra: R$ {media_amostra:.2f}")
print(f"Desvio-padrão da amostra: R$ {desvio_padrao_amostra:.2f}")
# Out:
# Média da amostra: R$ 1964.20
# Desvio-padrão da amostra: R$ 3139.89

# %% [markdown]
# ### Dados do problema

# %% [markdown]
# # <font color='blue'>Solução do item 2</font>

# %% [markdown]
# ### Obtenha a margem de erro
#
# #### <font color='red'>Lembre-se que a margem de erro deve estar na mesma unidade da variável que está sendo estudada (R$)</font>

# %%
import scipy.stats as stats

sigma = desvio_padrao_amostra

# Margem de erro especificada pelo cliente (10%)
margem_erro = 0.10

# Níveis de confiança desejados
confianca_90 = 0.90
confianca_95 = 0.95
confianca_99 = 0.99

# Calcula o valor crítico Z para cada nível de confiança
z_90 = stats.norm.ppf((1 + confianca_90) / 2)
z_95 = stats.norm.ppf((1 + confianca_95) / 2)
z_99 = stats.norm.ppf((1 + confianca_99) / 2)

# Calcula o tamanho da amostra para cada nível de confiança
tamanho_amostra_90 = ((z_90 ** 2) * (sigma ** 2)) / (margem_erro ** 2)
tamanho_amostra_95 = ((z_95 ** 2) * (sigma ** 2)) / (margem_erro ** 2)
tamanho_amostra_99 = ((z_99 ** 2) * (sigma ** 2)) / (margem_erro ** 2)

# Exibe os resultados
print(f"Tamanho da amostra para 90% de confiança: {round(tamanho_amostra_90)}")
print(f"Tamanho da amostra para 95% de confiança: {round(tamanho_amostra_95)}")
print(f"Tamanho da amostra para 99% de confiança: {round(tamanho_amostra_99)}")
# Out:
# Tamanho da amostra para 90% de confiança: 2667363111
# Tamanho da amostra para 95% de confiança: 3787248560
# Tamanho da amostra para 99% de confiança: 6541265642

# %% [markdown]
# ### Tamanho da amostra ($1 - \alpha = 90\%$)

# %%
# Out:
# Para um **nível de confiança de 90%** devemos selecionar uma amostra de **691 elementos**.

# %% [markdown]
# ### Tamanho da amostra ($1 - \alpha = 95\%$)

# %% [markdown]
# ### Tamanho da amostra ($1 - \alpha = 99\%$)

# %% [markdown]
# # <font color='blue'>Solução do item 3</font>

# %% [markdown]
# ### Custo da pesquisa para o nível de confiança de 90%

# %%
# Custo médio por indivíduo entrevistado
custo_medio_por_entrevista = 100.00

# Calcula o custo total da pesquisa para cada nível de confiança
custo_pesquisa_90 = tamanho_amostra_90 * custo_medio_por_entrevista
custo_pesquisa_95 = tamanho_amostra_95 * custo_medio_por_entrevista
custo_pesquisa_99 = tamanho_amostra_99 * custo_medio_por_entrevista

# Exibe os resultados
print(f"Custo da pesquisa para 90% de confiança: R$ {custo_pesquisa_90:.2f}")
print(f"Custo da pesquisa para 95% de confiança: R$ {custo_pesquisa_95:.2f}")
print(f"Custo da pesquisa para 99% de confiança: R$ {custo_pesquisa_99:.2f}")
# Out:
# Custo da pesquisa para 90% de confiança: R$ 266736311118.98
# Custo da pesquisa para 95% de confiança: R$ 378724856034.51
# Custo da pesquisa para 99% de confiança: R$ 654126564233.64

# %% [markdown]
# ### Custo da pesquisa para o nível de confiança de 95%

# %%
custo_pesquisa_95 = tamanho_amostra_95 * custo_medio_por_entrevista
print(f"Custo da pesquisa para 95% de confiança: R$ {custo_pesquisa_95:.2f}")
# Out:
# Custo da pesquisa para 95% de confiança: R$ 378724856034.51

# %% [markdown]
# ### Custo da pesquisa para o nível de confiança de 99%

# %%
custo_pesquisa_99 = tamanho_amostra_99 * custo_medio_por_entrevista
print(f"Custo da pesquisa para 99% de confiança: R$ {custo_pesquisa_99:.2f}")
# Out:
# Custo da pesquisa para 99% de confiança: R$ 654126564233.64

# %% [markdown]
# # <font color='blue'>Solução do item 4</font>

# %%
# Valor crítico Z para 95% de confiança
z_95 = stats.norm.ppf((1 + confianca_95) / 2)

# Calcula o erro padrão da média
erro_padrao_media = sigma / np.sqrt(tamanho_amostra_95)

# Calcula o intervalo de confiança
intervalo_confianca = (
    media_amostra - z_95 * erro_padrao_media,
    media_amostra + z_95 * erro_padrao_media
)

# Exibe o intervalo de confiança
print(f"Intervalo de Confiança (95%): R$ {intervalo_confianca[0]:.2f} - R$ {intervalo_confianca[1]:.2f}")
# Out:
# Intervalo de Confiança (95%): R$ 1964.11 - R$ 1964.30

# %% [markdown]
# # <font color='blue'>Solução do item 5</font>

# %%
# Calcula a margem de erro considerando o orçamento disponível
margem_erro_orcamento = np.sqrt((z_95 ** 2) * (sigma ** 2) / (tamanho_amostra_95)) * custo_medio_por_entrevista

# Exibe a margem de erro considerando o orçamento disponível
print(f"Margem de Erro (95%): R$ {margem_erro_orcamento:.2f}")
# Out:
# Margem de Erro (95%): R$ 10.00

# %% [markdown]
# # <font color='blue'>Solução do item 6</font>

# %%
# Nova margem de erro desejada (5%)
nova_margem_erro = 0.05

# Calcula o tamanho da amostra necessário para a nova margem de erro
necessario_tamanho_amostra = ((z_95 ** 2) * (sigma ** 2)) / (nova_margem_erro ** 2)

# Calcula o custo total da pesquisa para a nova margem de erro
custo_total_nova_margem_erro = necessario_tamanho_amostra * custo_medio_por_entrevista

# Exibe o custo total da pesquisa
print(f"Custo total da pesquisa para 5% de margem de erro: R$ {custo_total_nova_margem_erro:.2f}")
# Out:
# Custo total da pesquisa para 5% de margem de erro: R$ 1514899424138.06
