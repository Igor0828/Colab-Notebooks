# %%
import pandas as pd

notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["usuarioId", "FilmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  FilmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['nota']. value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
print("Media", notas['nota'].mean())
print("Mediana", notas['nota'].median())
# Out:
# Media 3.501556983616962
# Mediana 3.5

# %%
notas['nota'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas.nota)
# Out:
# <Axes: >

# %% [markdown]
# Revisando (media, mediana, moda, medias de tendencias central,dispersao, desvio padrao,boxplot, histograma).

# %%
filmes = pd.read_csv("movies.csv")
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
notas_do_toy_story = notas.query("FilmeId==1")
notas_do_jumanji = notas.query("FilmeId==2")
print(len(notas_do_toy_story), len(notas_do_jumanji))
# Out:
# 215 110

# %%
print("Nota média do Toy Story %.2f" % notas_do_toy_story.nota.mean())
print("Nota média do Jumanji %.2f" % notas_do_jumanji.nota.mean())
# Out:
# Nota média do Toy Story 3.92
# Nota média do Jumanji 3.43

# %%
import numpy as np

np.array([2.5] * 10)
# Out:
# array([2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5])

# %%
import numpy as np

np.array([2.5] * 10).mean()
# Out:
# 2.5

# %%
filme1 = np.append(np.array([2.5] * 10), np.array([3.5] * 10))
filme2 = np.append(np.array([5] * 10), np.array([1] * 10))
print(filme1.mean(), filme2.mean())
print(np.median(filme1), np.median(filme2))
# Out:
# 3.0 3.0
# 3.0 3.0

# %%
sns.boxplot(x = "FilmeId", y = "nota", data = notas.query("FilmeId in (1,2,3,4,5)"))
# Out:
# <Axes: xlabel='FilmeId', ylabel='nota'>

# %%
print("Desvio padrão do Jumanji %.2f" % notas_do_jumanji.nota.std(), "Desvio padrão do Toy Story %.2f" % notas_do_toy_story.nota.std())
# Out:
# Desvio padrão do Jumanji 0.88 Desvio padrão do Toy Story 0.83

# %%
print(np.mean(filme1), np.mean(filme2))
print(np.std(filme1), np.std(filme2))
print(np.median(filme1), np.median(filme2))
# Out:
# 3.0 3.0
# 0.5 2.0
# 3.0 3.0

# %% [markdown]
# # **Google Dataset Search**

# %%
plt.boxplot([notas_do_toy_story.nota, notas_do_jumanji.nota])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b09c51a3f40>,
#   <matplotlib.lines.Line2D at 0x7b09c51cc100>,
#   <matplotlib.lines.Line2D at 0x7b09c51cd0c0>,
#   <matplotlib.lines.Line2D at 0x7b09c51cd360>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b09c51cc3a0>,
#   <matplotlib.lines.Line2D at 0x7b09c51cc640>,
#   <matplotlib.lines.Line2D at 0x7b09c51cd600>,
#   <matplotlib.lines.Line2D at 0x7b09c51cd8a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b09c51a3ca0>,
#   <matplotlib.lines.Line2D at 0x7b09c51cce20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b09c51cc8e0>,
#   <matplotlib.lines.Line2D at 0x7b09c51cdb40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b09c51ccb80>,
#   <matplotlib.lines.Line2D at 0x7b09c51cdde0>],
#  'means': []}
